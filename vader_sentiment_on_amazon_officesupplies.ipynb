# %%
import re
import json
from itertools import islice

import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
with open('reviews_Office_Products_5.json', 'r') as reviews_file:
    for line in reviews_file:
        review = json.loads(line)
        for key in review.keys():
            fields.add(key)

# many entries lack reviewerName
# unixReviewTime is unique

# %%
sentiment_analyser = SentimentIntensityAnalyzer()
sentiment = {}

with open('reviews_Office_Products_5.json', 'r') as reviews_file:
    for line in islice(reviews_file, 999):
        review = json.loads(line)
        sentiment['unixReviewTime'] = sentiment_analyser.polarity_scores(review['reviewText'])['compound']

plt.plot([s['compound'] for s in sentiment])
# many entries lack reviewerName
# unixReviewTime is unique

# %%
fields
# Out:
# {'asin',
#  'helpful',
#  'overall',
#  'reviewText',
#  'reviewTime',
#  'reviewerID',
#  'reviewerName',
#  'summary',
#  'unixReviewTime'}
